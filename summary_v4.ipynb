# %%
import os
import pandas as pd

# 주어진 경로
folder_path = r"C:/Users/User/Downloads/도서자료 요약/Training/[원천]도서요약_train/기술과학"

# 빈 리스트 생성
data_list = []

# 경로 안에 있는 모든 JSON 파일 읽어오기
for filename in os.listdir(folder_path):
    if filename.endswith(".json"):
        file_path = os.path.join(folder_path, filename)
        # JSON 파일을 pandas DataFrame으로 읽어와서 리스트에 추가
        df = pd.read_json(file_path, encoding='utf-8')
        data_list.append(df[['passage', 'summary']])

# 데이터 리스트를 하나의 DataFrame으로 합치기
merged_data = pd.concat(data_list)

# 중복값 제거
merged_data = merged_data.drop_duplicates()

# CSV 파일로 저장
merged_data.to_csv("merged_data2.csv", index=False, encoding='utf-8-sig')

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import random
from mecab import MeCab
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request

# %%
raw = pd.read_csv('./merged_data2.csv')
df = raw.copy()

# %%
list_index = df[df.summary.duplicated()].index

# %%
df.head()
# Out:
#                                              passage  \
# 0  지금의 국가가 직면하는 위기는 전통사회의 그것과 위기의 규모뿐만아니라 종류와 성질 ...
# 1  자연재해나 불량 수산식품 파동 등의 인위적 재난이 수산분야 피해로이어질 경우 일반분...
# 2  하지만 이와 반대로 MG 파동 이후 기간(2005.10～2011.12)의 경우에는 ...
# 3  그러나 사회적 이슈가 발생하였을 경우에 전문적으로 이러한 정보를 수집하고 분석하는 ...
# 4  네 번째는 공급감소로 국내 물량이 부족하게 되면 유통질서가 왜곡될 가능성이 많기 때...
#
#                                              summary
# 0  현대 사회에서 발생하는 다양하고 복잡한 위기는 과거와 다르게 국가의 재난으로 이어질...
# 1  수산분야의 인위적 재난 시수산물 수급 문제로 생산자들의 매출이 크게 줄고, 시장 전...
# 2  MG 파동 이후에는 양식 송어의 생산량의 증가가 통계적 유의성을 갖는 것으로 드러났...
# 3  사회적 이슈 발생 시 전문적으로 정보 수집 및 분석을 하는 관측 시스템이 아직 구축...
# 4  일부 경우에서의 유통질서 혼란을 방지하기 위해 거래형태의 변형이 필요하다. 의도적 ...

# %%
list_index
# Out:
# Int64Index([  455,  3569,  3570,  3571,  3572,  3573,  3574,  3575,  3576,
#             10635,
#             ...
#             23284, 23285, 23286, 23288, 23289, 23293, 23295, 23296, 23300,
#             23301],
#            dtype='int64', length=394)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23918 entries, 0 to 23917
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   passage  23918 non-null  object
#  1   summary  23918 non-null  object
# dtypes: object(2)
# memory usage: 373.8+ KB

# %%
# for index in list_index:
#     df = df.drop(index)

# %%
df.isnull().sum()
# Out:
# passage    0
# summary    0
# dtype: int64

# %%
korean_josa_list = [
    '의', '에', '에서', '도', '이', '가', '을', '를',
    '은', '는', '과', '와', '으로', '에게', '부터', '까지',
    '만', '에서부터', '까지'
]

# %%
# 불용어(stopwords) 로드
stop_words = set()
with open("./stopwords.txt", 'r', encoding='utf-8') as f:
    for word in f.readlines():
        word = word.strip()
        if word not in korean_josa_list:
            stop_words.add(word)
# 형태소 분석기 초기화
mecab = MeCab()

# %%
def preprocess_text(text):
    token = mecab.morphs(text)
    return ' '.join(token)

# %%
df['PreprocessedText'] = df['passage'].apply(preprocess_text)

# %%
df['Pred_summary'] = df['summary'].apply(preprocess_text)

# %%
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower()  # 텍스트 소문자화
    sentence = re.sub(r"/([^)]*/)", "", sentence)  # 괄호로 닫힌 문자열 제거 Ex) 가나다 (abc) -> 가나다
    sentence = re.sub('"', "", sentence)  # 쌍따옴표 " 제거
    sentence = re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣]", " ", sentence)  # 한글과 영어, 숫자를 제외한 문자 공백으로 변환
    sentence = re.sub(" +", " ", sentence)

    # 불용어 제거
    if remove_stopwords:
        sentence = ' '.join(word for word in sentence.split() if word not in stop_words and len(word) > 1)
    else:
        sentence = ' '.join(word for word in sentence.split() if len(word) > 1)
    return sentence

# %%
df.head()
# Out:
#                                              passage  \
# 0  지금의 국가가 직면하는 위기는 전통사회의 그것과 위기의 규모뿐만아니라 종류와 성질 ...
# 1  자연재해나 불량 수산식품 파동 등의 인위적 재난이 수산분야 피해로이어질 경우 일반분...
# 2  하지만 이와 반대로 MG 파동 이후 기간(2005.10～2011.12)의 경우에는 ...
# 3  그러나 사회적 이슈가 발생하였을 경우에 전문적으로 이러한 정보를 수집하고 분석하는 ...
# 4  네 번째는 공급감소로 국내 물량이 부족하게 되면 유통질서가 왜곡될 가능성이 많기 때...
#
#                                              summary  \
# 0  현대 사회에서 발생하는 다양하고 복잡한 위기는 과거와 다르게 국가의 재난으로 이어질...
# 1  수산분야의 인위적 재난 시수산물 수급 문제로 생산자들의 매출이 크게 줄고, 시장 전...
# 2  MG 파동 이후에는 양식 송어의 생산량의 증가가 통계적 유의성을 갖는 것으로 드러났...
# 3  사회적 이슈 발생 시 전문적으로 정보 수집 및 분석을 하는 관측 시스템이 아직 구축...
# 4  일부 경우에서의 유통질서 혼란을 방지하기 위해 거래형태의 변형이 필요하다. 의도적 ...
#
#                                     PreprocessedText  \
# 0  지금 의 국가 가 직면 하 는 위기 는 전통 사회 의 그것 과 위기 의 규모 뿐 만...
# 1  자연재해 나 불량 수산 식품 파동 등 의 인위 적 재난 이 수산 분야 피해 로 이어...
# 2  하지만 이 와 반 대로 MG 파동 이후 기간 ( 2005 . 10 ～ 2011 . ...
# 3  그러나 사회 적 이슈 가 발생 하 였을 경우 에 전문 적 으로 이러 한 정보 를 수...
# 4  네 번 째 는 공급 감소 로 국내 물량 이 부족 하 게 되 면 유통 질서 가 왜곡 ...
#
#                                         Pred_summary
# 0  현대 사회 에서 발생 하 는 다양 하 고 복잡 한 위기 는 과거 와 다르 게 국가 ...
# 1  수산 분야 의 인위 적 재난 시수 산물 수급 문제 로 생산자 들 의 매출 이 크 게...
# 2  MG 파동 이후 에 는 양식 송어 의 생산량 의 증가 가 통계 적 유의 성 을 갖 ...
# 3  사회 적 이슈 발생 시 전문 적 으로 정보 수집 및 분석 을 하 는 관측 시스템 이...
# 4  일부 경우 에서 의 유통 질서 혼란 을 방지 하 기 위해 거래 형태 의 변형 이 필...

# %%
df['PreprocessedText'] = df['PreprocessedText'].apply(preprocess_sentence)

# %%
df.head()
# Out:
#                                              passage  \
# 0  지금의 국가가 직면하는 위기는 전통사회의 그것과 위기의 규모뿐만아니라 종류와 성질 ...
# 1  자연재해나 불량 수산식품 파동 등의 인위적 재난이 수산분야 피해로이어질 경우 일반분...
# 2  하지만 이와 반대로 MG 파동 이후 기간(2005.10～2011.12)의 경우에는 ...
# 3  그러나 사회적 이슈가 발생하였을 경우에 전문적으로 이러한 정보를 수집하고 분석하는 ...
# 4  네 번째는 공급감소로 국내 물량이 부족하게 되면 유통질서가 왜곡될 가능성이 많기 때...
#
#                                              summary  \
# 0  현대 사회에서 발생하는 다양하고 복잡한 위기는 과거와 다르게 국가의 재난으로 이어질...
# 1  수산분야의 인위적 재난 시수산물 수급 문제로 생산자들의 매출이 크게 줄고, 시장 전...
# 2  MG 파동 이후에는 양식 송어의 생산량의 증가가 통계적 유의성을 갖는 것으로 드러났...
# 3  사회적 이슈 발생 시 전문적으로 정보 수집 및 분석을 하는 관측 시스템이 아직 구축...
# 4  일부 경우에서의 유통질서 혼란을 방지하기 위해 거래형태의 변형이 필요하다. 의도적 ...
#
#                                     PreprocessedText  \
# 0  지금 국가 직면 위기 전통 사회 그것 위기 규모 종류 성질 에서 사뭇 다르 다고 현...
# 1  자연재해 불량 수산 식품 파동 인위 재난 수산 분야 피해 이어질 경우 일반 분야 마...
# 2  대로 파동 이후 기간 경우 모형 적합 변수 통계 유의 존재 으로 나타났 기간 지날수...
# 3  사회 이슈 발생 였을 경우 전문 으로 이러 정보 수집 분석 관측 시스템 존재 는다고...
# 4  공급 감소 국내 물량 부족 유통 질서 왜곡 가능 때문 직거래 특판 개설 거래 형태 ...
#
#                                         Pred_summary
# 0  현대 사회 에서 발생 하 는 다양 하 고 복잡 한 위기 는 과거 와 다르 게 국가 ...
# 1  수산 분야 의 인위 적 재난 시수 산물 수급 문제 로 생산자 들 의 매출 이 크 게...
# 2  MG 파동 이후 에 는 양식 송어 의 생산량 의 증가 가 통계 적 유의 성 을 갖 ...
# 3  사회 적 이슈 발생 시 전문 적 으로 정보 수집 및 분석 을 하 는 관측 시스템 이...
# 4  일부 경우 에서 의 유통 질서 혼란 을 방지 하 기 위해 거래 형태 의 변형 이 필...

# %%
df['Pred_summary'] = df['Pred_summary'].apply(preprocess_sentence)

# %%
df.rename(columns={'PreprocessedText': 'Pred_Text'}, inplace=True)

# %%
df.head()
# Out:
#                                              passage  \
# 0  지금의 국가가 직면하는 위기는 전통사회의 그것과 위기의 규모뿐만아니라 종류와 성질 ...
# 1  자연재해나 불량 수산식품 파동 등의 인위적 재난이 수산분야 피해로이어질 경우 일반분...
# 2  하지만 이와 반대로 MG 파동 이후 기간(2005.10～2011.12)의 경우에는 ...
# 3  그러나 사회적 이슈가 발생하였을 경우에 전문적으로 이러한 정보를 수집하고 분석하는 ...
# 4  네 번째는 공급감소로 국내 물량이 부족하게 되면 유통질서가 왜곡될 가능성이 많기 때...
#
#                                              summary  \
# 0  현대 사회에서 발생하는 다양하고 복잡한 위기는 과거와 다르게 국가의 재난으로 이어질...
# 1  수산분야의 인위적 재난 시수산물 수급 문제로 생산자들의 매출이 크게 줄고, 시장 전...
# 2  MG 파동 이후에는 양식 송어의 생산량의 증가가 통계적 유의성을 갖는 것으로 드러났...
# 3  사회적 이슈 발생 시 전문적으로 정보 수집 및 분석을 하는 관측 시스템이 아직 구축...
# 4  일부 경우에서의 유통질서 혼란을 방지하기 위해 거래형태의 변형이 필요하다. 의도적 ...
#
#                                            Pred_Text  \
# 0  지금 국가 직면 위기 전통 사회 그것 위기 규모 종류 성질 에서 사뭇 다르 다고 현...
# 1  자연재해 불량 수산 식품 파동 인위 재난 수산 분야 피해 이어질 경우 일반 분야 마...
# 2  대로 파동 이후 기간 경우 모형 적합 변수 통계 유의 존재 으로 나타났 기간 지날수...
# 3  사회 이슈 발생 였을 경우 전문 으로 이러 정보 수집 분석 관측 시스템 존재 는다고...
# 4  공급 감소 국내 물량 부족 유통 질서 왜곡 가능 때문 직거래 특판 개설 거래 형태 ...
#
#                                         Pred_summary
# 0  현대 사회 에서 발생 다양 복잡 위기 과거 다르 국가 재난 으로 이어질 으므로 국가...
# 1  수산 분야 인위 재난 시수 산물 수급 문제 생산자 매출 시장 전체 생산자 잉여 감소...
# 2  파동 이후 양식 송어 생산량 증가 통계 유의 으로 드러났 통해 파동 이후 양식 송어...
# 3  사회 이슈 발생 전문 으로 정보 수집 분석 관측 시스템 아직 구축 정확 관측 단기 ...
# 4  일부 경우 에서 유통 질서 혼란 방지 위해 거래 형태 변형 필요 의도 물량 창출 시...

# %%
df.replace('', np.nan, inplace=True)
print(df.isnull().sum())
# Out:
# passage         0
# summary         0
# Pred_Text       0
# Pred_summary    0
# dtype: int64

# %%
df.dropna(axis = 0, inplace = True)
print('전체 샘플수 :',(len(df)))
# Out:
# 전체 샘플수 : 23918

# %%
text_len = [len(s.split()) for s in df['Pred_Text']]
summary_len = [len(s.split()) for s in df['Pred_summary']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(summary_len)
plt.title('Summary')
plt.subplot(1,2,2)
plt.boxplot(text_len)
plt.title('Text')
plt.tight_layout()
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Text')
plt.hist(text_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 6
# 텍스트의 최대 길이 : 253
# 텍스트의 평균 길이 : 92.29103603980266
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 81
# 요약의 평균 길이 : 26.665356635170166

# %%
text_max_len = 160
summary_max_len = 50

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, df['Pred_Text'])
# Out:
# 전체 샘플 중 길이가 160 이하인 샘플의 비율: 0.9605318170415587

# %%
below_threshold_len(summary_max_len, df['Pred_summary'])
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.976879337737269

# %%
df = df[df['Pred_Text'].apply(lambda x: len(x.split()) <= text_max_len)]
df = df[df['Pred_summary'].apply(lambda x: len(x.split()) <= summary_max_len)]
print('전체 샘플수 :',(len(df)))
# Out:
# 전체 샘플수 : 22845

# %%
df.head()
# Out:
#                                              passage  \
# 0  지금의 국가가 직면하는 위기는 전통사회의 그것과 위기의 규모뿐만아니라 종류와 성질 ...
# 1  자연재해나 불량 수산식품 파동 등의 인위적 재난이 수산분야 피해로이어질 경우 일반분...
# 2  하지만 이와 반대로 MG 파동 이후 기간(2005.10～2011.12)의 경우에는 ...
# 3  그러나 사회적 이슈가 발생하였을 경우에 전문적으로 이러한 정보를 수집하고 분석하는 ...
# 4  네 번째는 공급감소로 국내 물량이 부족하게 되면 유통질서가 왜곡될 가능성이 많기 때...
#
#                                              summary  \
# 0  현대 사회에서 발생하는 다양하고 복잡한 위기는 과거와 다르게 국가의 재난으로 이어질...
# 1  수산분야의 인위적 재난 시수산물 수급 문제로 생산자들의 매출이 크게 줄고, 시장 전...
# 2  MG 파동 이후에는 양식 송어의 생산량의 증가가 통계적 유의성을 갖는 것으로 드러났...
# 3  사회적 이슈 발생 시 전문적으로 정보 수집 및 분석을 하는 관측 시스템이 아직 구축...
# 4  일부 경우에서의 유통질서 혼란을 방지하기 위해 거래형태의 변형이 필요하다. 의도적 ...
#
#                                            Pred_Text  \
# 0  지금 국가 직면 위기 전통 사회 그것 위기 규모 종류 성질 에서 사뭇 다르 다고 현...
# 1  자연재해 불량 수산 식품 파동 인위 재난 수산 분야 피해 이어질 경우 일반 분야 마...
# 2  대로 파동 이후 기간 경우 모형 적합 변수 통계 유의 존재 으로 나타났 기간 지날수...
# 3  사회 이슈 발생 였을 경우 전문 으로 이러 정보 수집 분석 관측 시스템 존재 는다고...
# 4  공급 감소 국내 물량 부족 유통 질서 왜곡 가능 때문 직거래 특판 개설 거래 형태 ...
#
#                                         Pred_summary
# 0  현대 사회 에서 발생 다양 복잡 위기 과거 다르 국가 재난 으로 이어질 으므로 국가...
# 1  수산 분야 인위 재난 시수 산물 수급 문제 생산자 매출 시장 전체 생산자 잉여 감소...
# 2  파동 이후 양식 송어 생산량 증가 통계 유의 으로 드러났 통해 파동 이후 양식 송어...
# 3  사회 이슈 발생 전문 으로 정보 수집 분석 관측 시스템 아직 구축 정확 관측 단기 ...
# 4  일부 경우 에서 유통 질서 혼란 방지 위해 거래 형태 변형 필요 의도 물량 창출 시...

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
df['decoder_input'] = df['Pred_summary'].apply(lambda x : 'sostoken '+ x)
df['decoder_target'] = df['Pred_summary'].apply(lambda x : x + ' eostoken')
df.head()
# Out:
#                                              passage  \
# 0  지금의 국가가 직면하는 위기는 전통사회의 그것과 위기의 규모뿐만아니라 종류와 성질 ...
# 1  자연재해나 불량 수산식품 파동 등의 인위적 재난이 수산분야 피해로이어질 경우 일반분...
# 2  하지만 이와 반대로 MG 파동 이후 기간(2005.10～2011.12)의 경우에는 ...
# 3  그러나 사회적 이슈가 발생하였을 경우에 전문적으로 이러한 정보를 수집하고 분석하는 ...
# 4  네 번째는 공급감소로 국내 물량이 부족하게 되면 유통질서가 왜곡될 가능성이 많기 때...
#
#                                              summary  \
# 0  현대 사회에서 발생하는 다양하고 복잡한 위기는 과거와 다르게 국가의 재난으로 이어질...
# 1  수산분야의 인위적 재난 시수산물 수급 문제로 생산자들의 매출이 크게 줄고, 시장 전...
# 2  MG 파동 이후에는 양식 송어의 생산량의 증가가 통계적 유의성을 갖는 것으로 드러났...
# 3  사회적 이슈 발생 시 전문적으로 정보 수집 및 분석을 하는 관측 시스템이 아직 구축...
# 4  일부 경우에서의 유통질서 혼란을 방지하기 위해 거래형태의 변형이 필요하다. 의도적 ...
#
#                                            Pred_Text  \
# 0  지금 국가 직면 위기 전통 사회 그것 위기 규모 종류 성질 에서 사뭇 다르 다고 현...
# 1  자연재해 불량 수산 식품 파동 인위 재난 수산 분야 피해 이어질 경우 일반 분야 마...
# 2  대로 파동 이후 기간 경우 모형 적합 변수 통계 유의 존재 으로 나타났 기간 지날수...
# 3  사회 이슈 발생 였을 경우 전문 으로 이러 정보 수집 분석 관측 시스템 존재 는다고...
# 4  공급 감소 국내 물량 부족 유통 질서 왜곡 가능 때문 직거래 특판 개설 거래 형태 ...
#
#                                         Pred_summary  \
# 0  현대 사회 에서 발생 다양 복잡 위기 과거 다르 국가 재난 으로 이어질 으므로 국가...
# 1  수산 분야 인위 재난 시수 산물 수급 문제 생산자 매출 시장 전체 생산자 잉여 감소...
# 2  파동 이후 양식 송어 생산량 증가 통계 유의 으로 드러났 통해 파동 이후 양식 송어...
# 3  사회 이슈 발생 전문 으로 정보 수집 분석 관측 시스템 아직 구축 정확 관측 단기 ...
# 4  일부 경우 에서 유통 질서 혼란 방지 위해 거래 형태 변형 필요 의도 물량 창출 시...
#
#                                        decoder_input  \
# 0  sostoken 현대 사회 에서 발생 다양 복잡 위기 과거 다르 국가 재난 으로 이...
# 1  sostoken 수산 분야 인위 재난 시수 산물 수급 문제 생산자 매출 시장 전체 ...
# 2  sostoken 파동 이후 양식 송어 생산량 증가 통계 유의 으로 드러났 통해 파동...
# 3  sostoken 사회 이슈 발생 전문 으로 정보 수집 분석 관측 시스템 아직 구축 ...
# 4  sostoken 일부 경우 에서 유통 질서 혼란 방지 위해 거래 형태 변형 필요 의...
#
#                                       decoder_target
# 0  현대 사회 에서 발생 다양 복잡 위기 과거 다르 국가 재난 으로 이어질 으므로 국가...
# 1  수산 분야 인위 재난 시수 산물 수급 문제 생산자 매출 시장 전체 생산자 잉여 감소...
# 2  파동 이후 양식 송어 생산량 증가 통계 유의 으로 드러났 통해 파동 이후 양식 송어...
# 3  사회 이슈 발생 전문 으로 정보 수집 분석 관측 시스템 아직 구축 정확 관측 단기 ...
# 4  일부 경우 에서 유통 질서 혼란 방지 위해 거래 형태 변형 필요 의도 물량 창출 시...

# %%
encoder_input = np.array(df['Pred_Text'])
decoder_input = np.array(df['decoder_input'])
decoder_target = np.array(df['decoder_target'])

# %%
import random

indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [15737 13690  7311 ... 19316  9253  9860]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :',n_of_val)
# Out:
# 테스트 데이터의 수 : 4569

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

# %%
print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :',len(decoder_input_train))
print('테스트 데이터의 개수 :',len(encoder_input_test))
print('테스트 레이블의 개수 :',len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 18276
# 훈련 레이블의 개수 : 18276
# 테스트 데이터의 개수 : 4569
# 테스트 레이블의 개수 : 4569

# %%
src_tokenizer = Tokenizer()
src_tokenizer.fit_on_texts(encoder_input_train)

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 35029
# 등장 빈도가 6번 이하인 희귀 단어의 수: 24748
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 10281
# 단어 집합에서 희귀 단어의 비율: 70.6500328299409
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.1374474347413646

# %%
src_vocab = 10000
src_tokenizer = Tokenizer(num_words = src_vocab) 
src_tokenizer.fit_on_texts(encoder_input_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# %%
print(encoder_input_train[:3])
# Out:
# [[481, 34, 1338, 563, 535, 17, 774, 563, 99, 736, 2458, 2, 645, 81, 801, 17, 2, 210, 46, 1142, 563, 49, 2786, 195, 2127, 2514, 539, 17, 373, 309, 563, 659, 50, 600, 923, 307, 563, 51, 11, 34, 539, 1, 1146, 9, 34, 36, 563, 124, 49, 1180, 9, 3235, 2608, 244, 193, 909, 68, 291, 397, 1029, 304, 34, 89, 211, 452, 38], [2127, 2631, 239, 160, 4933, 2514, 539, 239, 30, 288, 2271, 9, 168, 30, 888, 1231, 185, 191, 185, 653, 867, 45, 49, 31, 36, 867, 45, 49, 9, 1231, 185, 120, 191, 185, 1301, 555, 1403, 42, 41, 156, 173, 1301, 4194, 185, 31, 888, 275, 9, 1231, 185, 9, 44, 41, 276, 1030, 87, 275, 4194, 185, 31, 239, 160, 4933, 191, 185, 9, 275, 4194, 185, 1301, 4194, 549, 156, 1, 17, 4288, 185, 28, 1086, 31], [1232, 4933, 123, 228, 9, 302, 541, 443, 349, 621, 207, 1, 183, 228, 8837, 466, 7485, 1231, 621, 1, 67, 1, 20, 36, 20, 28, 402, 1, 9, 466, 7485, 1231, 47, 4933, 314, 228, 123, 228, 1, 127, 319, 1, 10, 1412, 545, 4933, 1231, 544, 127, 4933, 123, 466, 7485, 1231, 314, 127, 185, 1, 183, 1231, 67, 544, 8838, 314, 127, 4122, 202, 70, 1, 382, 4933, 123, 466, 7485, 64, 3983, 536, 3632]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 19718
# 등장 빈도가 5번 이하인 희귀 단어의 수: 14264
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 5454
# 단어 집합에서 희귀 단어의 비율: 72.33999391419007
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 5.251317269551832

# %%
tar_vocab = 5400
tar_tokenizer = Tokenizer(num_words = tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# %%
print(decoder_input_train[:5])
# Out:
# [[2, 732, 20, 4, 64, 46, 543, 454, 546, 393, 32, 341, 1, 2435, 547, 32, 1026, 292, 262, 11], [2, 207, 35, 2592, 341, 2786, 803, 37, 1194, 497, 43, 252, 1194, 3398, 154, 235, 43, 254, 1027, 24, 208, 255, 3398, 154, 36], [2, 129, 463, 1277, 62, 377, 825, 1, 2787, 25, 129, 463, 70, 4955, 601, 3118], [2, 20, 385, 64, 161, 1, 17, 452, 19, 626, 57, 518, 98, 619, 626, 784, 292, 201, 389], [2, 426, 51, 4, 488, 1710, 1504, 564, 15, 394, 228, 1388, 11, 1440, 2180, 223, 43, 3257, 3009, 572, 1811, 11]]

# %%
print(decoder_target_train[:5])
# Out:
# [[732, 20, 4, 64, 46, 543, 454, 546, 393, 32, 341, 1, 2435, 547, 32, 1026, 292, 262, 11, 3], [207, 35, 2592, 341, 2786, 803, 37, 1194, 497, 43, 252, 1194, 3398, 154, 235, 43, 254, 1027, 24, 208, 255, 3398, 154, 36, 3], [129, 463, 1277, 62, 377, 825, 1, 2787, 25, 129, 463, 70, 4955, 601, 3118, 3], [20, 385, 64, 161, 1, 17, 452, 19, 626, 57, 518, 98, 619, 626, 784, 292, 201, 389, 3], [426, 51, 4, 488, 1710, 1504, 564, 15, 394, 228, 1388, 11, 1440, 2180, 223, 43, 3257, 3009, 572, 1811, 11, 3]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

# %%
print('삭제할 훈련 데이터의 개수 :',len(drop_train))
print('삭제할 테스트 데이터의 개수 :',len(drop_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 0
# 삭제할 테스트 데이터의 개수 : 0

# %%
# encoder_input_train = np.delete(encoder_input_train, drop_train, axis=0)
# decoder_input_train = np.delete(decoder_input_train, drop_train, axis=0)
# decoder_target_train = np.delete(decoder_target_train, drop_train, axis=0)

# encoder_input_test = np.delete(encoder_input_test, drop_test, axis=0)
# decoder_input_test = np.delete(decoder_input_test, drop_test, axis=0)
# decoder_target_test = np.delete(decoder_target_test, drop_test, axis=0)

# print('훈련 데이터의 개수 :', len(encoder_input_train))
# print('훈련 레이블의 개수 :',len(decoder_input_train))
# print('테스트 데이터의 개수 :',len(encoder_input_test))
# print('테스트 레이블의 개수 :',len(decoder_input_test))

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen = text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen = text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen = summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen = summary_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen = summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen = summary_max_len, padding='post')

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# 디코더
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences = True, return_state = True, dropout = 0.4, recurrent_dropout=0.2)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state = [state_h, state_c])
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation = 'softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 160)]        0           []
#
#  embedding_1 (Embedding)        (None, 160, 128)     1280000     ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, 160, 256),   394240      ['embedding_1[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  input_3 (InputLayer)           [(None, None)]       0           []
#
#  lstm_1 (LSTM)                  [(None, 160, 256),   525312      ['lstm[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_2 (Embedding)        (None, None, 128)    691200      ['input_3[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 160, 256),   525312      ['lstm_1[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_3 (LSTM)                  [(None, None, 256),  394240      ['embedding_2[0][0]',
#                                  (None, 256),                     'lstm_2[0][1]',
#                                  (None, 256)]                     'lstm_2[0][2]']
#
#  dense (Dense)                  (None, None, 5400)   1387800     ['lstm_3[0][0]']
#
# ==================================================================================================
# Total params: 5,198,104
# Trainable params: 5,198,104
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/ukairia777/tensorflow-nlp-tutorial/main/20.%20Text%20Summarization%20with%20Attention/attention.py", filename="attention.py")
from attention import AttentionLayer

# %%
# 어텐션 층(어텐션 함수)
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis = -1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 160)]        0           []
#
#  embedding_1 (Embedding)        (None, 160, 128)     1280000     ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, 160, 256),   394240      ['embedding_1[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  input_3 (InputLayer)           [(None, None)]       0           []
#
#  lstm_1 (LSTM)                  [(None, 160, 256),   525312      ['lstm[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_2 (Embedding)        (None, None, 128)    691200      ['input_3[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 160, 256),   525312      ['lstm_1[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_3 (LSTM)                  [(None, None, 256),  394240      ['embedding_2[0][0]',
#                                  (None, 256),                     'lstm_2[0][1]',
#                                  (None, 256)]                     'lstm_2[0][2]']
#
#  attention_layer (AttentionLaye  ((None, None, 256),  131328     ['lstm_2[0][0]',
#  r)                              (None, None, 160))               'lstm_3[0][0]']
#
#  concat_layer (Concatenate)     (None, None, 512)    0           ['lstm_3[0][0]',
#                                                                   'attention_layer[0][0]']
#
#  dense_1 (Dense)                (None, None, 5400)   2770200     ['concat_layer[0][0]']
#
# ==================================================================================================
# Total params: 6,711,832
# Trainable params: 6,711,832
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience = 2)
history = model.fit(x = [encoder_input_train, decoder_input_train], y = decoder_target_train, \
          validation_data = ([encoder_input_test, decoder_input_test], decoder_target_test),
          batch_size = 128, callbacks=[es], epochs = 30)
# Out:
# Epoch 1/30
#  93/143 [==================>...........] - ETA: 1:19 - loss: 3.8753
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 2
#       1 es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience = 2)
# ----> 2 history = model.fit(x = [encoder_input_train, decoder_input_train], y = decoder_target_train, \
#       3           validation_data = ([encoder_input_test, decoder_input_test], decoder_target_test),
#       4           batch_size = 128, callbacks=[es], epochs = 30)
#
# File c:\Users\User\anaconda3\envs\hee\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\User\anaconda3\envs\hee\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save('model6.h5')

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
#  seq2seq + attention으로 요약 모델 테스트하기

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# %%
# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)
# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if(sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    sentence=''
    for i in input_seq:
        if(i!=0):
            sentence = sentence + src_index_to_word[i]+' '
    return sentence

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    sentence=''
    for i in input_seq:
        if((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            sentence = sentence + tar_index_to_word[i] + ' '
    return sentence

# %%
from rouge import Rouge
rouge = Rouge()

# %%
for i in range(500, 1000):
    print("원문 : ",seq2text(encoder_input_test[i]))
    print("실제 요약문 :",seq2summary(decoder_input_test[i]))
    print("예측 요약문 :",decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("rouge scores: ",rouge.get_scores(decode_sequence(encoder_input_test[1].reshape(1, text_max_len)), seq2summary(decoder_input_test[1]) , avg= True))
    print("\n")
# Out:
# 원문 :  약물 경구 지질 영향 는다 지질 진정 중추 신경 흡수 비율 결정 중요 므로 지질 매우 빠르 흡수 된다 모든 진정 임신 태반 장벽 통과 므로 임신 신생아 에서 생명 기능 억제 초래 약물 대사 통해 배설 된다 약물 상태 에서 활성 사물 전환 활성 물질 으로 생체 변환 된다 약물 대사 으로 전환 까지 단계 거치 면서 활성 으로 오래 머물 수록 약물 작용 지속 경향 보인다 약물 경우 누적 효과 인하 부작용 나타날
# 실제 요약문 : 계열 약물 부작용 지질 임신 약물 누적 효과 나타날
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 예측 요약문 :  고관절 치환 수술 정맥 혈전 색전증 예방 으로 발생 한다 에서 발생 는데 감염 발생 므로 발생 므로 발생 으로 발생 한다
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# rouge scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}}
#
#
# 원문 :  약물 으로 단기 사용 대한 적응증 가지 장기 사용 이후 사용 유용 부족 의존 남용 증상 때문 약물 관련 지침 에서 권고 는다 장기 사용 인지 기능 인지 장애 잠재 악화 일으킬 다고 추정
# 실제 요약문 : 약물 장기 사용 유용 부족 의존 문제 발생 인지 기능 인지 장애 잠재 으로 악화 시킬
# 1/1 [==============================] - 0s 451ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 예측 요약문 :  연구 에서 환자 에게 사용 약물 사용 환자 에게 사용 한다 혈액 사용 환자 에게 사용 한다
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# rouge scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}}
#
#
# 원문 :  특히 최근 시행 연구 에서 노인 환자 처방 으며 처방 약물 지속 작용 가진 신경 질환 불안 증상 처방 경우 수면 장애 통증 관련 질환 관절염 환자 질환 약물 질병 상호 작용 때문 여가 권고 동반 질환 만성 폐색 폐질환 환자 처방 빈도 로서 으로 나타났 지속 작용 가진 처방 차지 선행 연구 비하 처방 대체 약물 권고 처방 증가 긍정 방향 으로 판단
# 실제 요약문 : 최근 시행 연구 에서 지속 작용 지닌 처방 선행 연구 비해서 처방 증가 긍정 으로 판단
# 1/1 [==============================] - 0s 459ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 예측 요약문 :  혈압 환자 대상 으로 혈압 혈압 혈압 혈압 혈압 혈압 혈압 혈압 혈압 혈압 진단 혈압 질환 동반 질환 질환 질환 질환 질환 질환 질환 질환 질환 고도
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# rouge scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}}
#
#
# 원문 :  검색 모든 문헌 사전 정의 아래 배제 기준 검토 연구 필요 문헌 선정 문헌 선택 위해 독립 검토 그룹 으로 나누 그룹 에서 검토 독립 으로 평가 합의 선택 과정 에서 연구자 제목 검토 연구 문헌 배제 선택 과정 에서 그룹 으로 연구자 선택 초록 검토 연구 문헌 선정 선택 문헌 사용 현황 차량 사고 인지 기능 장애 지침 자살 골절 낙상 안전 임신 관련 교육 중재 내용 으로 분류 원문 구독 문헌 검토 원문 검토 통하 적합 주제 논문 선정 정리 요약
# 실제 요약문 : 연구 필요 문헌 선정 위해 검토 연구 문헌 배제 검토 검토 적합 주제 논문 선정 정리 요약
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 예측 요약문 :  문헌 고찰 결과 문헌 검토 문헌 고찰 결과 평가 문헌 근거 근거 선정 근거 선정 근거 선정 순위 선정 순위 선정 순위 선정
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# rouge scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}}
#
#
# 원문 :  아일랜드 에서 수행 연구 로서 일반 에게 문헌 에서 확인 처방 척도 순위 매기 설문 행하 였으며 별도 처방 베이스 동일 처방 척도 적용 분석 일반 순위 에서 장기 사용 중요 처방 척도 인식 실제 으로 처방 데이터베이스 분석 결과 에서 사용 였으며 장기 사용 초과 척도 적용 어서 이론 임상 현실 사이 차이 확인
# 실제 요약문 : 일반 순위 에서 장기 사용 중요 처방 척도 인식 실제 으로 사용 초과 사용
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 예측 요약문 :  연구 에서 보청기 사용 위해 보청기 사용 만족도 효과 으로 나타났
# 1/1 [==============================] - 0s 273ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# rouge scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}}
#
#
# 원문 :  지역 에서 부터 까지 처방 패턴 확인 논문 복용 사람 단기 작용 제제 사용 권고 기준 적용 부터 까지 사용 증가 였으나 증가 진정 사용 포함 계열 약물 사용 비해 어서 대한 추가 연구 필요 다는 의견 제시
# 실제 요약문 : 처방 패턴 연구 논문 에서 증가 계열 약물 비해 유해 므로 대한 추가 연구 된다고
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 예측 요약문 :  미국 에서 까지 까지 까지 까지 까지 증가 환자 증가 의료비 감소 의료비 감소 의료비 지출 감소
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# rouge scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}}
#
#
# 원문 :  연구 개월 기간 스위스 지역 약국 에서 조제 기록 이용 개월 복용 사람 으로 환산 복용 사람 에서 고령자 에서 반복 해서 복용 사람 권고 용량 초과 사용 사람 반복 사용 에서 로서 환산 계산 가장 빈번 사용 순서 사용
# 실제 요약문 : 따르 스위스 에서 복용 사람 반복 해서 약물 복용 사람 가장 자주 이용 약물
# 1/1 [==============================] - 0s 461ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 예측 요약문 :  흡입제 사용 사람 에게 사용 거나 복용 한다 복용 복용 으로 인한 복용
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 27ms/step
# rouge scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}}
#
#
# 원문 :  세계 생물 정신 학회 에서 장애 불안 강박 환자 약제 사용 대한 가이드라인 개정 약제 처방 권고 제시 는데 까지 에서 출판 임상 연구 논문 중심 근거 기반 으로 국제 전문가 패널 합의 개발 지침 에서 장애 환자 에서 치료 약제 과거 의존 으면 사용 효과 우울증 초기 처방 단계 에서 효과 나타나 에서 약제 가능 다고 제시 불안 장애 환자 에서 치료 약제 과거 의존 환자 에서 사용 효과 다고 언급 으며 복용 상대 으로 전하 약물 존성 이내 처방 권고 진정 반응 지연 인지 기능 운전 부작용 나타날 처방 제시
# 실제 요약문 : 세계 생물 정신 학회 장애 불안 환자 에게 치료 약제 사용 가이드라인 개정 약제 처방 권고 제시 국제 전문가 패널 까지 에서 출판 임상 연구 논문 중심 근거 토대 합의 개발 으로 환자 상황 효과 약제 사용법 부작용 정리
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 예측 요약문 :  정신 질환 대한 관심 입원 으로 인해 입원 기간 으로 인한 질병 예방 가능 질병 예방 위한 질병 예방 위한 질병 예방 위한 약물 약물 치료 필요
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 23ms/step
# rouge scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}}
#
#
# 원문 :  미국 유럽 에서 주요 우울 장애 치료 가이드라인 대해 문헌 고찰 임상 정신 의학 저널 논문 게재 는데 논문 우울증 국제 합의 그룹 원탁회의 거쳐서 수록 계약 대해 약제 효과 빠르 지속 처방 권장 으며 약제 존성 으로 불안 우울 장애 치료 단독 요법 으로 사용 으며 제한 으로 사용 어야 한다고 권고 미국 정신 의사 협회 따르 심한 우울증 경우 정맥 주사제 사용 효과 으며 단기 보조 치료 제한 미국 정신 의사 협회 영국 정신 임상 협회 영국 보건 의료 연구소 텍사스 약제 가이드 프로젝트 가이드라인 에서 약제 사용 불안 증상 가진 환자 에게 단기 요법 사용 권고 고는 으나 미국 정신 의사 협회 캐나다 에서 약제 존성 우울증 초기 치료 장기 요법 제한 영국 약제 우울 효과 다고 제시
# 실제 요약문 : 논문 의견 우울증 국제 합의 그룹 통해 수록 계약 일정 기간 투약 단독 으로 사용 불가 한다 심한 우울증 치료제 사용 기에 단기 보조 치료 사용 다고 한다 더불 연구소 프로젝트 에서 해당 복용 대해 다양 의견 제시
# 1/1 [==============================] - 0s 477ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 예측 요약문 :  전이 환자 치료 대상 으로 환자 에게 통증 발생 한다 약물 치료 효과 치료 효과 으로 나타났
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# rouge scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}}
#
#
# 원문 :  연구 에서 증상 나타내 불안 장애 환자 정신 약물 치료 대해 미국 응급 학회 합의 거쳐 논문 으로 발표 는데 다양 상황 에서 급성 불안 장애 환자 치료 경우 약제 사용 고려 으며 대한 가이드라인 제공 약제 급성 불안 증상 대해 일시 증상 완화 목적 으로 초기 치료 약제 사용 으며 효과 빠르 나타나 환자 진정 시킬 으나 유발 근본 질환 치료 다고 언급
# 실제 요약문 : 연구 급성 불안 장애 환자 치료 일시 증상 완화 목적 치료 약제 약제 사용 고려 다고 가이드라인 제공 한다
# 1/1 [==============================] - 0s 422ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  혈압 치료 효과 연구 에서 당뇨병 발생 므로 연구 에서 발생 는데 만성 질환 질환 발생 므로 연구 필요
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# rouge scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.3333333333333333, 'f': 0.16666666291666676}}
#
#
# 원문 :  이탈리아 규모 역학 연구 바탕 으로 정신 리스트 포함 합의 기관 이탈리아 수면 학회 통하 일반 치료 가이드라인 정립 제시 약제 효과 약제 비해 부작용 위험 으로 선택 으로 사용 단기 기억 장애 인지 장애 약제 의존 낙상 골절 위험 증가 호흡기 부작용 으로 정신 전문의 처방 도록 권고
# 실제 요약문 : 이탈리아 일반 치료 가이드라인 제시 효과 기억 장애 부작용 정신 전문 처방 권고 한다
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 예측 요약문 :  정신 장애 입원 입원 기간 입원 입원 기간 입원 기간 정신 장애 입원 입원 정신 장애
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20496\554914016.py in ?()
#       1 for i in range(500, 1000):
#       2     print("원문 : ",seq2text(encoder_input_test[i]))
#       3     print("실제 요약문 :",seq2summary(decoder_input_test[i]))
#       4     print("예측 요약문 :",decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
# ----> 5     print("rouge scores: ",rouge.get_scores(decode_sequence(encoder_input_test[1].reshape(1, text_max_len)), seq2summary(decoder_input_test[1]) , avg= True))
#       6     print("\n")
#
# ~\AppData\Local\Temp\ipykernel_20496\757967483.py in ?(input_seq)
#       9     stop_condition = False
#      10     decoded_sentence = ''
#      11     while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복
#      12
# ---> 13         output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
#      14         sampled_token_index = np.argmax(output_tokens[0, -1, :])
#      15         sampled_token = tar_index_to_word[sampled_token_index]
#      16
#
# c:\Users\User\anaconda3\envs\hee\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\User\anaconda3\envs\hee\lib\site-packages\keras\engine\training.py in ?(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2282                     "`tf.config.run_functions_eagerly(True)` for more "
#    2283                     "information of where went wrong, or file a "
#    2284                     "issue/bug to `tf.keras`."
#    2285                 )
# -> 2286             callbacks.on_predict_end()
#    2287         all_outputs = tf.__internal__.nest.map_structure_up_to(
#    2288             batch_outputs, potentially_ragged_concat, outputs
#    2289         )
#
# c:\Users\User\anaconda3\envs\hee\lib\site-packages\keras\engine\data_adapter.py in ?(self)
#    1370             or self._current_step < self._inferred_steps
#    1371         ):
#    1372             if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1373                 break
# -> 1374             original_spe = self._steps_per_execution.numpy().item()
#    1375             can_run_full_execution = (
#    1376                 original_spe == 1
#    1377                 or self._inferred_steps is None
#
# c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in ?(self)
#     635   def numpy(self):
#     636     if context.executing_eagerly():
# --> 637       return self.read_value().numpy()
#     638     raise NotImplementedError(
#     639         "numpy() is only available when eager execution is enabled.")
#
# c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in ?(self)
#     724     with ops.name_scope("Read"):
#     725       value = self._read_variable_op()
#     726     # Return an identity so it can get placed on whatever device the context
#     727     # specifies instead of the device where the variable is.
# --> 728     return array_ops.identity(value)
#
# c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#    1181         if result is not OpDispatcher.NOT_SUPPORTED:
#    1182           return result
#    1183         else:
# -> 1184           raise
#
# c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\ops\array_ops.py in ?(input, name)
#     290   if context.executing_eagerly() and not hasattr(input, "graph"):
#     291     # Make sure we get an input with handle data attached from resource
#     292     # variables. Variables have correct handle data when graph building.
#     293     input = ops.convert_to_tensor(input)
# --> 294   ret = gen_array_ops.identity(input, name=name)
#     295   # Propagate handle data for happier shape inference for resource variables.
#     296   if hasattr(input, "_handle_data"):
#     297     ret._handle_data = input._handle_data  # pylint: disable=protected-access
#
# c:\Users\User\anaconda3\envs\hee\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in ?(input, name)
#    4070       return _result
#    4071     except _core._NotOkStatusException as e:
#    4072       _ops.raise_from_not_ok_status(e, name)
#    4073     except _core._FallbackException:
# -> 4074       pass
#    4075     try:
#    4076       return identity_eager_fallback(
#    4077           input, name=name, ctx=_ctx)
#
# KeyboardInterrupt:

# %%
import nltk.translate.bleu_score as bleu
print('실습 코드의 BLEU :',bleu_score(decode_sequence(encoder_input_test[i].reshape(1, text_max_len)).split(),list(map(lambda ref: ref.split(), seq2text(encoder_input_test[i])))))
print('패키지 NLTK의 BLEU :',bleu.sentence_bleu(list(map(lambda ref: ref.split(), references)),decode_sequence(encoder_input_test[i].reshape(1, text_max_len)).split()))

# %%
model.save('model3.h5')
